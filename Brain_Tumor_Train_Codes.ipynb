# %%
import os

# %%
import glob

# %%
from IPython.display import Image, display

# %%
#display.clear_output()

# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# WARNING ⚠️ 'yolo mode=checks' is deprecated. Use 'yolo checks' instead.
# Ultralytics YOLOv8.0.118 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.1/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="t7fkXsXAO1VQRseI8Zsv")
project = rf.workspace("braintumor-ulfxx").project("braintumor-2zcl0")
dataset = project.version(1).download("yolov8")
# Out:
# /content
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.4 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=bd1bad18d88bff595bc15f86fcbaca93538f17545055cc594e6a02da2a34745f
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=20 imgsz=640
# Out:
# /content
# ...
# 100% 131M/131M [00:07<00:00, 19.2MB/s]
# Ultralytics YOLOv8.0.118 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.35 source='/content/braintumor-1/valid/images'
# Out:
# WARNING ⚠️ user config directory is not writeable, defaulting to '/tmp/Ultralytics'.
# Ultralytics YOLOv8.0.116 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients
#
# image 1/441 /content/braintumor-1/valid/images/Cancer-100-_jpg.rf.4da2281f0fc9768528d02ddef2031240.jpg: 640x640 (no detections), 97.3ms
# image 2/441 /content/braintumor-1/valid/images/Cancer-1003-_jpg.rf.07c541c0db96418cd4efffe64477a908.jpg: 640x640 1 tumor, 54.5ms
# image 3/441 /content/braintumor-1/valid/images/Cancer-1006-_jpg.rf.ac087021a8f7f0f9598c90d375722ce6.jpg: 640x640 1 tumor, 52.3ms
# image 4/441 /content/braintumor-1/valid/images/Cancer-1010-_jpg.rf.037ee2fe003308ba4fc0e2cef934d270.jpg: 640x640 1 tumor, 52.8ms
# image 5/441 /content/braintumor-1/valid/images/Cancer-1011-_jpg.rf.c8ce49bddeffbf47ef0d1e0c0b69e8a2.jpg: 640x640 1 tumor, 53.6ms
# ...
